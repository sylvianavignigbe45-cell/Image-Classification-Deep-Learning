# %%
# ============================================================
# IMAGE CLASSIFICATION WITH DEEP LEARNING
# Fashion-MNIST Classification
# Google Colab Project
# ============================================================

# ============================================================
# 1. IMPORT LIBRARIES
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
    Input,
    Flatten,
    Dense,
    Dropout
)
from tensorflow.keras.datasets import fashion_mnist
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score
)

print("TensorFlow version:", tf.__version__)
print("Libraries imported successfully!")


# ============================================================
# 2. LOAD FASHION-MNIST DATASET
# ============================================================

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

print("\nDataset loaded successfully!")

print("Training images:", X_train.shape)
print("Testing images:", X_test.shape)


# ============================================================
# 3. DEFINE CLASS NAMES
# ============================================================

class_names = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]


# ============================================================
# 4. DISPLAY SAMPLE IMAGES
# ============================================================

plt.figure(figsize=(12, 6))

for i in range(12):

    plt.subplot(3, 4, i + 1)

    plt.imshow(
        X_train[i],
        cmap="gray"
    )

    plt.title(
        class_names[y_train[i]]
    )

    plt.axis("off")

plt.tight_layout()
plt.show()


# ============================================================
# 5. CHECK CLASS DISTRIBUTION
# ============================================================

unique_classes, counts = np.unique(
    y_train,
    return_counts=True
)

class_distribution = pd.DataFrame({
    "Class": [
        class_names[i]
        for i in unique_classes
    ],
    "Count": counts
})

print("\nClass distribution:")

display(class_distribution)


plt.figure(figsize=(10, 5))

sns.barplot(
    data=class_distribution,
    x="Class",
    y="Count"
)

plt.title("Fashion-MNIST Class Distribution")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ============================================================
# 6. NORMALIZE IMAGE PIXEL VALUES
# ============================================================

X_train = X_train.astype("float32") / 255.0

X_test = X_test.astype("float32") / 255.0

print("\nPixel values normalized.")

print(
    "Minimum pixel value:",
    X_train.min()
)

print(
    "Maximum pixel value:",
    X_train.max()
)


# ============================================================
# 7. BUILD NEURAL NETWORK
# ============================================================

model = Sequential([

    Input(shape=(28, 28)),

    Flatten(),

    Dense(
        128,
        activation="relu"
    ),

    Dropout(0.2),

    Dense(
        64,
        activation="relu"
    ),

    Dropout(0.2),

    Dense(
        10,
        activation="softmax"
    )
])


# ============================================================
# 8. DISPLAY MODEL ARCHITECTURE
# ============================================================

print("\nModel architecture:")

model.summary()


# ============================================================
# 9. COMPILE MODEL
# ============================================================

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

print("\nModel compiled successfully!")


# ============================================================
# 10. TRAIN MODEL
# ============================================================

history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    verbose=1
)

print("\nModel training completed!")


# ============================================================
# 11. EVALUATE MODEL
# ============================================================

test_loss, test_accuracy = model.evaluate(
    X_test,
    y_test,
    verbose=0
)

print("\n============================================================")
print("MODEL PERFORMANCE")
print("============================================================")

print(
    "Test Loss:",
    round(test_loss, 4)
)

print(
    "Test Accuracy:",
    round(test_accuracy * 100, 2),
    "%"
)


# ============================================================
# 12. TRAINING HISTORY
# ============================================================

history_df = pd.DataFrame(
    history.history
)

display(history_df)


# ============================================================
# 13. TRAINING VS VALIDATION ACCURACY
# ============================================================

plt.figure(figsize=(9, 5))

plt.plot(
    history.history["accuracy"],
    label="Training Accuracy"
)

plt.plot(
    history.history["val_accuracy"],
    label="Validation Accuracy"
)

plt.title("Training vs Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.show()


# ============================================================
# 14. TRAINING VS VALIDATION LOSS
# ============================================================

plt.figure(figsize=(9, 5))

plt.plot(
    history.history["loss"],
    label="Training Loss"
)

plt.plot(
    history.history["val_loss"],
    label="Validation Loss"
)

plt.title("Training vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()


# ============================================================
# 15. MAKE PREDICTIONS
# ============================================================

probabilities = model.predict(
    X_test,
    verbose=0
)

y_pred = np.argmax(
    probabilities,
    axis=1
)

print("\nPredictions generated successfully!")


# ============================================================
# 16. CLASSIFICATION REPORT
# ============================================================

print("\n============================================================")
print("CLASSIFICATION REPORT")
print("============================================================")

print(
    classification_report(
        y_test,
        y_pred,
        target_names=class_names
    )
)


# ============================================================
# 17. CONFUSION MATRIX
# ============================================================

cm = confusion_matrix(
    y_test,
    y_pred
)

plt.figure(figsize=(10, 8))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()


# ============================================================
# 18. DISPLAY CORRECT AND INCORRECT PREDICTIONS
# ============================================================

correct_indices = np.where(
    y_pred == y_test
)[0]

incorrect_indices = np.where(
    y_pred != y_test
)[0]


# ============================================================
# 19. CORRECT PREDICTIONS
# ============================================================

plt.figure(figsize=(12, 8))

for i, index in enumerate(
    correct_indices[:12]
):

    plt.subplot(3, 4, i + 1)

    plt.imshow(
        X_test[index],
        cmap="gray"
    )

    plt.title(
        f"Predicted: {class_names[y_pred[index]]}"
    )

    plt.axis("off")

plt.tight_layout()
plt.show()


# ============================================================
# 20. INCORRECT PREDICTIONS
# ============================================================

plt.figure(figsize=(12, 8))

for i, index in enumerate(
    incorrect_indices[:12]
):

    plt.subplot(3, 4, i + 1)

    plt.imshow(
        X_test[index],
        cmap="gray"
    )

    plt.title(
        f"Actual: {class_names[y_test[index]]}\n"
        f"Predicted: {class_names[y_pred[index]]}"
    )

    plt.axis("off")

plt.tight_layout()
plt.show()


# ============================================================
# 21. PREDICTION CONFIDENCE
# ============================================================

prediction_confidence = np.max(
    probabilities,
    axis=1
)

confidence_df = pd.DataFrame({
    "Actual": [
        class_names[i]
        for i in y_test
    ],
    "Predicted": [
        class_names[i]
        for i in y_pred
    ],
    "Confidence": prediction_confidence
})

confidence_df["Correct"] = (
    confidence_df["Actual"]
    == confidence_df["Predicted"]
)

print("\nPrediction confidence:")

display(
    confidence_df.head(10)
)


# ============================================================
# 22. SAVE PREDICTIONS
# ============================================================

confidence_df.to_csv(
    "fashion_mnist_predictions.csv",
    index=False
)

history_df.to_csv(
    "training_history.csv",
    index=False
)

print("\nPrediction and training files saved!")


# ============================================================
# 23. SAVE TRAINED MODEL
# ============================================================

model.save(
    "fashion_mnist_classifier.keras"
)

print(
    "\nTrained model saved as:",
    "fashion_mnist_classifier.keras"
)


# ============================================================
# 24. FINAL PROJECT SUMMARY
# ============================================================

print("""
============================================================
IMAGE CLASSIFICATION WITH DEEP LEARNING COMPLETED
============================================================

✓ Fashion-MNIST dataset loaded
✓ Sample images visualized
✓ Class distribution analyzed
✓ Pixel values normalized
✓ Neural network created
✓ Model compiled
✓ Model trained
✓ Training history analyzed
✓ Test accuracy calculated
✓ Predictions generated
✓ Classification report created
✓ Confusion matrix created
✓ Correct predictions visualized
✓ Incorrect predictions visualized
✓ Prediction confidence analyzed
✓ Predictions exported
✓ Training history exported
✓ Trained model saved

============================================================
PROJECT INFORMATION
============================================================

Project Name : Image Classification with Deep Learning
Dataset      : Fashion-MNIST
Task         : Image Classification
Framework    : TensorFlow / Keras
Model        : Neural Network
Environment  : Google Colab

============================================================
""")
# Out:
# TensorFlow version: 2.20.0
# Libraries imported successfully!
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# Dataset loaded successfully!
# Training images: (60000, 28, 28)
# Testing images: (10000, 28, 28)
# Class distribution:
#          Class  Count
# 0  T-shirt/top   6000
# 1      Trouser   6000
# 2     Pullover   6000
# 3        Dress   6000
# 4         Coat   6000
# 5       Sandal   6000
# 6        Shirt   6000
# 7      Sneaker   6000
# 8          Bag   6000
# 9   Ankle boot   6000
# Pixel values normalized.
# Minimum pixel value: 0.0
# Maximum pixel value: 1.0
#
# Model architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)
# Model compiled successfully!
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - accuracy: 0.7588 - loss: 0.6837 - val_accuracy: 0.8422 - val_loss: 0.4400
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8355 - loss: 0.4588 - val_accuracy: 0.8599 - val_loss: 0.3857
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8517 - loss: 0.4154 - val_accuracy: 0.8675 - val_loss: 0.3663
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8624 - loss: 0.3822 - val_accuracy: 0.8683 - val_loss: 0.3576
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8675 - loss: 0.3674 - val_accuracy: 0.8763 - val_loss: 0.3443
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8723 - loss: 0.3503 - val_accuracy: 0.8723 - val_loss: 0.3457
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8752 - loss: 0.3394 - val_accuracy: 0.8748 - val_loss: 0.3447
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8809 - loss: 0.3290 - val_accuracy: 0.8777 - val_loss: 0.3316
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8823 - loss: 0.3213 - val_accuracy: 0.8826 - val_loss: 0.3252
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8861 - loss: 0.3104 - val_accuracy: 0.8819 - val_loss: 0.3261
#
# Model training completed!
#
# ============================================================
# MODEL PERFORMANCE
# ============================================================
# Test Loss: 0.3539
# Test Accuracy: 87.6 %
#    accuracy      loss  val_accuracy  val_loss
# 0  0.758792  0.683669      0.842250  0.440049
# 1  0.835458  0.458791      0.859917  0.385669
# 2  0.851667  0.415383      0.867500  0.366287
# 3  0.862354  0.382192      0.868333  0.357573
# 4  0.867458  0.367441      0.876250  0.344300
# 5  0.872312  0.350312      0.872333  0.345710
# 6  0.875229  0.339353      0.874833  0.344724
# 7  0.880917  0.328952      0.877667  0.331637
# 8  0.882292  0.321306      0.882583  0.325210
# 9  0.886146  0.310416      0.881917  0.326069
# Predictions generated successfully!
#
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.80      0.88      0.84      1000
#      Trouser       0.98      0.97      0.97      1000
#     Pullover       0.78      0.80      0.79      1000
#        Dress       0.90      0.87      0.89      1000
#         Coat       0.71      0.86      0.78      1000
#       Sandal       0.97      0.96      0.96      1000
#        Shirt       0.80      0.53      0.64      1000
#      Sneaker       0.93      0.96      0.94      1000
#          Bag       0.95      0.98      0.96      1000
#   Ankle boot       0.97      0.94      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.87     10000
# weighted avg       0.88      0.88      0.87     10000
# Prediction confidence:
#        Actual   Predicted  Confidence  Correct
# 0  Ankle boot  Ankle boot    0.940065     True
# 1    Pullover    Pullover    0.996742     True
# 2     Trouser     Trouser    1.000000     True
# 3     Trouser     Trouser    0.999999     True
# 4       Shirt       Shirt    0.859863     True
# 5     Trouser     Trouser    0.999990     True
# 6        Coat        Coat    0.978386     True
# 7       Shirt       Shirt    0.977595     True
# 8      Sandal      Sandal    0.999949     True
# 9     Sneaker     Sneaker    0.998000     True
# Prediction and training files saved!
#
# Trained model saved as: fashion_mnist_classifier.keras
#
# ============================================================
# IMAGE CLASSIFICATION WITH DEEP LEARNING COMPLETED
# ============================================================
#
# ✓ Fashion-MNIST dataset loaded
# ✓ Sample images visualized
# ✓ Class distribution analyzed
# ✓ Pixel values normalized
# ✓ Neural network created
# ✓ Model compiled
# ✓ Model trained
# ✓ Training history analyzed
# ✓ Test accuracy calculated
# ✓ Predictions generated
# ✓ Classification report created
# ✓ Confusion matrix created
# ✓ Correct predictions visualized
# ✓ Incorrect predictions visualized
# ✓ Prediction confidence analyzed
# ✓ Predictions exported
# ✓ Training history exported
# ✓ Trained model saved
#
# ============================================================
# PROJECT INFORMATION
# ============================================================
#
# Project Name : Image Classification with Deep Learning
# Dataset      : Fashion-MNIST
# Task         : Image Classification
# Framework    : TensorFlow / Keras
# Model        : Neural Network
# Environment  : Google Colab
#
# ============================================================
